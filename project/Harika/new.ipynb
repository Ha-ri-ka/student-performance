# %%
import pandas as pd
path="D:/labs/ML/project/code/dataset/xAPI-Edu-Data.csv"
RawData=pd.read_csv(path,delimiter=',')
RawData
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04         A
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3        M          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father           15                16
# 1           IT        F   Father           20                20
# 2           IT        F   Father           10                 7
# 3           IT        F   Father           30                25
# 4           IT        F   Father           40                50
# ..         ...      ...      ...          ...               ...
# 475  Chemistry        S   Father            5                 4
# 476    Geology        F   Father           50                77
# 477    Geology        S   Father           55                74
# 478    History        F   Father           30                17
# 479    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 0                    2          20                   Yes
# 1                    3          25                   Yes
# 2                    0          30                    No
# 3                    5          35                    No
# 4                   12          50                    No
# ..                 ...         ...                   ...
# 475                  5           8                    No
# 476                 14          28                    No
# 477                 25          29                    No
# 478                 14          57                    No
# 479                 23          62                    No
#
#     ParentschoolSatisfaction StudentAbsenceDays Class
# 0                       Good            Under-7     M
# 1                       Good            Under-7     M
# 2                        Bad            Above-7     L
# 3                        Bad            Above-7     L
# 4                        Bad            Above-7     M
# ..                       ...                ...   ...
# 475                      Bad            Above-7     L
# 476                      Bad            Under-7     M
# 477                      Bad            Under-7     M
# 478                      Bad            Above-7     L
# 479                      Bad            Above-7     L
#
# [480 rows x 17 columns]

# %%
selectedColumns=['raisedhands','VisITedResources','AnnouncementsView','Discussion','ParentAnsweringSurvey','StudentAbsenceDays','ParentschoolSatisfaction','Class']
data=RawData[selectedColumns]
data
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0             15                16                  2          20
# 1             20                20                  3          25
# 2             10                 7                  0          30
# 3             30                25                  5          35
# 4             40                50                 12          50
# ..           ...               ...                ...         ...
# 475            5                 4                  5           8
# 476           50                77                 14          28
# 477           55                74                 25          29
# 478           30                17                 14          57
# 479           35                14                 23          62
#
#     ParentAnsweringSurvey StudentAbsenceDays ParentschoolSatisfaction Class
# 0                     Yes            Under-7                     Good     M
# 1                     Yes            Under-7                     Good     M
# 2                      No            Above-7                      Bad     L
# 3                      No            Above-7                      Bad     L
# 4                      No            Above-7                      Bad     M
# ..                    ...                ...                      ...   ...
# 475                    No            Above-7                      Bad     L
# 476                    No            Under-7                      Bad     M
# 477                    No            Under-7                      Bad     M
# 478                    No            Above-7                      Bad     L
# 479                    No            Above-7                      Bad     L
#
# [480 rows x 8 columns]

# %%
data['StudentAbsenceDays'].unique()
data.replace({'Under-7':0,'Above-7':1},inplace=True)
data.replace({'No':0,'Yes':1},inplace=True)
data.replace({'M':1,'L':0,'H':2},inplace=True)
data.replace({'Good':1,'Bad':0},inplace=True)
data
# Out:
# C:\Users\Harika\AppData\Local\Temp\ipykernel_18592\1765689210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace({'Under-7':0,'Above-7':1},inplace=True)
# C:\Users\Harika\AppData\Local\Temp\ipykernel_18592\1765689210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace({'No':0,'Yes':1},inplace=True)
# C:\Users\Harika\AppData\Local\Temp\ipykernel_18592\1765689210.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace({'M':1,'L':0,'H':2},inplace=True)
# C:\Users\Harika\AppData\Local\Temp\ipykernel_18592\1765689210.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace({'Good':1,'Bad':0},inplace=True)
#      raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0             15                16                  2          20
# 1             20                20                  3          25
# 2             10                 7                  0          30
# 3             30                25                  5          35
# 4             40                50                 12          50
# ..           ...               ...                ...         ...
# 475            5                 4                  5           8
# 476           50                77                 14          28
# 477           55                74                 25          29
# 478           30                17                 14          57
# 479           35                14                 23          62
#
#      ParentAnsweringSurvey  StudentAbsenceDays  ParentschoolSatisfaction  \
# 0                        1                   0                         1
# 1                        1                   0                         1
# 2                        0                   1                         0
# 3                        0                   1                         0
# 4                        0                   1                         0
# ..                     ...                 ...                       ...
# 475                      0                   1                         0
# 476                      0                   0                         0
# 477                      0                   0                         0
# 478                      0                   1                         0
# 479                      0                   1                         0
#
#      Class
# 0        1
# 1        1
# 2        0
# 3        0
# 4        1
# ..     ...
# 475      0
# 476      1
# 477      1
# 478      0
# 479      0
#
# [480 rows x 8 columns]

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
logCopy=data.copy()
x=logCopy.iloc[:,:-1]
y=logCopy.iloc[:,-1]
x
# Out:
#      raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# 0             15                16                  2          20
# 1             20                20                  3          25
# 2             10                 7                  0          30
# 3             30                25                  5          35
# 4             40                50                 12          50
# ..           ...               ...                ...         ...
# 475            5                 4                  5           8
# 476           50                77                 14          28
# 477           55                74                 25          29
# 478           30                17                 14          57
# 479           35                14                 23          62
#
#      ParentAnsweringSurvey  StudentAbsenceDays  ParentschoolSatisfaction
# 0                        1                   0                         1
# 1                        1                   0                         1
# 2                        0                   1                         0
# 3                        0                   1                         0
# 4                        0                   1                         0
# ..                     ...                 ...                       ...
# 475                      0                   1                         0
# 476                      0                   0                         0
# 477                      0                   0                         0
# 478                      0                   1                         0
# 479                      0                   1                         0
#
# [480 rows x 7 columns]

# %%
Features=(logCopy.columns.tolist())
Features.remove('Class')
Target=logCopy['Class']
print(Target)
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 475    0
# 476    1
# 477    1
# 478    0
# 479    0
# Name: Class, Length: 480, dtype: int64

# %%
from sklearn.model_selection  import train_test_split 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=52)
model = LogisticRegression(solver='liblinear')
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
Score = accuracy_score(y_test,y_pred)
Report = classification_report(y_test,y_pred)

# %%
print(y_pred)
# Out:
# [0 1 0 0 1 0 2 2 1 1 1 0 2 0 2 0 2 1 2 1 2 2 0 0 2 0 2 1 2 0 1 2 0 2 1 1 0
#  1 2 0 1 1 2 1 2 0 1 0 1 0 2 2 1 2 1 0 1 0 0 2 0 2 1 1 1 2 0 0 2 1 2 2 2 2
#  2 2 1 2 2 2 0 2 1 1 0 1 1 2 1 2 0 1 1 2 2 2]

# %%
print(Score)
# Out:
# 0.7916666666666666

# %% [markdown]
# ## MULTIPLE LINEAR REGRESSION
